# %% [markdown]
# # __Массивы__

# %% [markdown]
# __07.03.2026__

# %% [markdown]
# ## __Два указателя__

# %% [markdown]
# - Тип 1: Fast/Slow - оба сначала
# - Тип 2: Left/Right - с краёы навстречу

# %% [markdown]
# ### __[Remove Duplicates](https://leetcode.com/problems/remove-duplicates-from-sorted-array/description/) (LeetCode #26)__ <br>

# %%
def removeDuplicates(nums):
    if not nums:
        return 0
    slow = 0
    
    for fast in range(1, len(nums)):
        if nums[fast] != nums[slow]:
            slow += 1
            nums[slow] = nums[fast]
    
    return slow + 1

# %% [markdown]
# ### __[Move Zeros](https://leetcode.com/problems/move-zeroes/) (LeetCode #283)__ <br>

# %%
nums = [4,2,4,0,0,3,0,5,1,0]
moveZeroes(nums)
nums
# Out:
# [4, 0, 0, 0, 0, 3, 2, 5, 1, 4]

# %% [markdown]
# Пример 1:
#
# Входные данные: nums = [0,1,0,3,12]
#  Выходные данные: [1,3,12,0,0]

# %% [markdown]
# ## __Префиксные суммы__

# %% [markdown]
# ### __Построение префиксных сумм__

# %%
def runningSum(nums):
        prefix = [nums[0]]

        for num in nums:
            prefix.append(prefix[-1] + num)
            
        return prefix

# %%
nums = [1,2,3,4]
runningSum(nums)
# Out:
# [1, 2, 4, 7, 11]

# %%
arr = list(map(int, input().split()))
prefix = [0]

for num in arr:
    prefix.append(prefix[-1] + num)
    
left, right = map(int, input().split())

print(arr)
print(prefix)
print(left, right)
print(prefix[right+1] - prefix[left+1])
# Out:
# [3, 4, 1, 5, 1]
# [0, 3, 7, 8, 13, 14]
# 1 3
# 6
